# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('movies.csv')

# %%
df['YEAR']
# Out:
# 0             -2021
# 1          (2021– )
# 2       (2010–2022)
# 3          (2013– )
# 4             -2021
#            ...
# 9994       (2021– )
# 9995       (2021– )
# 9996       (2022– )
# 9997       (2021– )
# 9998       (2021– )
# Name: YEAR, Length: 9999, dtype: object

# %%
df['YEAR'] = df['YEAR'].str.replace('[^0-9]', ' ',regex=True)
df['ONE-LINE'] = df['ONE-LINE'].str.replace('[^a-zA-Z]', ' ',regex=True)
df['STARS'] = df['STARS'].str.replace('[^a-zA-Z]', ' ',regex=True)

# %%
df.head()
# Out:
#                                 MOVIES         YEAR
# 0                        Blood Red Sky         2021  \
# 1  Masters of the Universe: Revelation      2021
# 2                     The Walking Dead   2010 2022
# 3                       Rick and Morty      2013
# 4                      Army of Thieves         2021
#
#                                         GENRE  RATING
# 0      \nAction, Horror, Thriller                 6.1  \
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE
# 0   A woman with a mysterious illness is forced i...  \
# 1   The war for Eternia begins again in what may ...
# 2   Sheriff Deputy Rick Grimes wakes up from a co...
# 3   An animated series that follows the exploits ...
# 4   A prequel  set before the events of Army of t...
#
# ...

# %%
df['YEAR']=df['YEAR'].replace([-2021,],2021)

# %%
df['YEAR']
# Out:
# 0              2021
# 1           2021
# 2        2010 2022
# 3           2013
# 4              2021
#            ...
# 9994        2021
# 9995        2021
# 9996        2022
# 9997        2021
# 9998        2021
# Name: YEAR, Length: 9999, dtype: object

# %%
df['GENRE']
# Out:
# 0           \nAction, Horror, Thriller
# 1       \nAnimation, Action, Adventure
# 2            \nDrama, Horror, Thriller
# 3       \nAnimation, Adventure, Comedy
# 4              \nAction, Crime, Horror
#                            ...
# 9994       \nAdventure, Drama, Fantasy
# 9995    \nAnimation, Action, Adventure
# 9996              \nDocumentary, Sport
# 9997       \nAdventure, Drama, Fantasy
# 9998       \nAdventure, Drama, Fantasy
# Name: GENRE, Length: 9999, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %%
df['Genre']=df['GENRE'].str.replace('[^a-zA-Z]','',regex=True)

# %%
df['Genre']=df['GENRE'].replace(['/','n','%','#'], '',regex=True)

# %%
df.iloc[0:9999,0:10]
# Out:
#                                    MOVIES         YEAR
# 0                           Blood Red Sky         2021  \
# 1     Masters of the Universe: Revelation      2021
# 2                        The Walking Dead   2010 2022
# 3                          Rick and Morty      2013
# 4                         Army of Thieves         2021
# ...                                   ...          ...
# 9994                       The Imperfects      2021
# 9995                               Arcane      2021
# 9996                    Heart of Invictus      2022
# 9997                       The Imperfects      2021
# 9998                       The Imperfects      2021
#
#                                            GENRE  RATING
# 0         \nAction, Horror, Thriller                 6.1  \
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df.drop(['Genre'],axis=1,inplace=True)

# %%
df.drop(['Gross'],axis=1,inplace=True)

# %%
df.dropna()
# Out:
#                                    MOVIES         YEAR
# 0                           Blood Red Sky         2021  \
# 1     Masters of the Universe: Revelation      2021
# 2                        The Walking Dead   2010 2022
# 3                          Rick and Morty      2013
# 5                             Outer Banks      2020
# ...                                   ...          ...
# 9959                               Sexify      2021
# 9960                               Sexify      2021
# 9961                               Sexify      2021
# 9962                               Sexify      2021
# 9963                          Castlevania   2017 2021
#
#                                            GENRE  RATING
# 0         \nAction, Horror, Thriller                 6.1  \
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df['GENRE']=df['GENRE'].replace('[^a-zA-z]',' ',regex=True)

# %%
df.dropna().head(1000)
# Out:
#                                      MOVIES          YEAR
# 0                             Blood Red Sky          2021  \
# 1       Masters of the Universe: Revelation       2021
# 2                          The Walking Dead    2010 2022
# 3                            Rick and Morty       2013
# 5                               Outer Banks       2020
# ...                                     ...           ...
# 1059                            Psycho-Pass       2012
# 1060                                    Cam          2018
# 1061  Kono subarashii sekai ni shukufuku o!    2016 2017
# 1062                       Leyla ile Mecnun    2011 2021
# 1063                   Boyka: Undisputed IV   2016
#
#                                           GENRE  RATING
# 0          Action  Horror  Thriller                 6.1  \
# 1      Animation  Action  Adventure                 5.0
# 2           Drama  Horror  Thriller                 8.2
# 3      Animation  Adventure  Comedy                 9.2
# ...

# %%
df
# Out:
#                                    MOVIES         YEAR
# 0                           Blood Red Sky         2021  \
# 1     Masters of the Universe: Revelation      2021
# 2                        The Walking Dead   2010 2022
# 3                          Rick and Morty      2013
# 4                         Army of Thieves         2021
# ...                                   ...          ...
# 9994                       The Imperfects      2021
# 9995                               Arcane      2021
# 9996                    Heart of Invictus      2022
# 9997                       The Imperfects      2021
# 9998                       The Imperfects      2021
#
#                                           GENRE  RATING
# 0          Action  Horror  Thriller                 6.1  \
# 1      Animation  Action  Adventure                 5.0
# 2           Drama  Horror  Thriller                 8.2
# 3      Animation  Adventure  Comedy                 9.2
# ...

# %%
sns.set(rc={'figure.figsize':(65,5)})
ax=sns.countplot(x = 'MOVIES' ,data=df2)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
df2=df.dropna().head(20)

# %%
df2
# Out:
#                                  MOVIES         YEAR
# 0                         Blood Red Sky         2021  \
# 1   Masters of the Universe: Revelation      2021
# 2                      The Walking Dead   2010 2022
# 3                        Rick and Morty      2013
# 5                           Outer Banks      2020
# 6       The Last Letter from Your Lover         2021
# 7                                Dexter   2006 2013
# 8                     Never Have I Ever      2020
# 9                          Virgin River      2019
# 10                  Gunpowder Milkshake         2021
# 11                              Lucifer   2016 2021
# 12                    Fear Street: 1994         2021
# 14                American Horror Story      2011
# 15                       Grey's Anatomy      2005
# 16                         Breaking Bad   2008 2013
# 17                      The Good Doctor      2017
# 18                             Atypical   2017 2021
# ...

# %%
movie_rating=df2.groupby('MOVIES',as_index=False)['RATING'].sum().sort_values(by='RATING',ascending=False)

# %%
sns.set(rc={'figure.figsize':(45,25)})
ax=sns.barplot(x = 'MOVIES', y ='RATING', data=movie_rating)
